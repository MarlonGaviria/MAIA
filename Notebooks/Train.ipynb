# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("steubk/wikiart")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Download already complete (33662671673 bytes).
# Extracting files...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 4
#       1 import kagglehub
#       3 # Download latest version
# ----> 4 path = kagglehub.dataset_download("steubk/wikiart")
#       6 print("Path to dataset files:", path)
#
# File c:\Users\user\OneDrive\Escritorio\Maestria IA\Maestria_General_venv\lib\site-packages\kagglehub\datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File c:\Users\user\OneDrive\Escritorio\Maestria IA\Maestria_General_venv\lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\user\OneDrive\Escritorio\Maestria IA\Maestria_General_venv\lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)
#      27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File c:\Users\user\OneDrive\Escritorio\Maestria IA\Maestria_General_venv\lib\site-packages\kagglehub\http_resolver.py:132, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     129 # First, we download the archive.
#     130 api_client.download_file(url_path, archive_path, h)
# --> 132 _extract_archive(archive_path, out_path)
#     134 # Delete the archive
#     135 os.remove(archive_path)
#
# File c:\Users\user\OneDrive\Escritorio\Maestria IA\Maestria_General_venv\lib\site-packages\kagglehub\http_resolver.py:269, in _extract_archive(archive_path, out_path)
#     267 elif zipfile.is_zipfile(archive_path):
#     268     with zipfile.ZipFile(archive_path, "r") as f:
# --> 269         f.extractall(out_path)
#     270 else:
#     271     msg = "Unsupported archive type."
#
# File ~\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1642, in ZipFile.extractall(self, path, members, pwd)
#    1639     path = os.fspath(path)
#    1641 for zipinfo in members:
# -> 1642     self._extract_member(zipinfo, path, pwd)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\zipfile.py:1697, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1693     return targetpath
#    1695 with self.open(member, pwd=pwd) as source, \
#    1696      open(targetpath, "wb") as target:
# -> 1697     shutil.copyfileobj(source, target)
#    1699 return targetpath
#
# File ~\AppData\Local\Programs\Python\Python39\lib\shutil.py:208, in copyfileobj(fsrc, fdst, length)
#     206 if not buf:
#     207     break
# --> 208 fdst_write(buf)
#
# OSError: [Errno 28] No space left on device

# %%
import pandas as pd
import numpy as np
